# %% [markdown]
# # **Comparitive Analysis**

# %% [markdown]
# **K-Means Clustering**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 5
ind = np.arange(N) 
width = 0.25

# %%
KmeansVals = [27.67, 25.67, 19.87, 17.54, 9.25]
bar1 = plt.bar(ind, KmeansVals, width, color = 'crimson')

# %% [markdown]
# **Mini-Batch Kmeans Clustering**

# %%
MiniBatchKmeansVals = [27.45, 25.53, 19.07, 18.43, 9.52]
bar2 = plt.bar(ind, MiniBatchKmeansVals, width, color='lightgreen')

# %% [markdown]
# **Agglomerative Clustering**

# %%
AgglomerativeVals = [38.1, 22.3, 17.8, 12.5, 9.34]
bar3 = plt.bar(ind,AgglomerativeVals, width, color = 'lightskyblue')

# %%
KmeansVals = [27.67, 25.67, 19.87, 17.54, 9.25]
bar1 = plt.bar(ind, KmeansVals, width, color = 'crimson')

MiniBatchKmeansVals = [27.45, 25.53, 19.07, 18.43, 9.52]
bar2 = plt.bar(ind+width, MiniBatchKmeansVals, width, color='lightgreen')

AgglomerativeVals = [38.1, 22.3, 17.8, 12.5, 9.34]
bar3 = plt.bar(ind+width*2,AgglomerativeVals, width, color = 'lightskyblue')

plt.xlabel("Clustering Algorithms")
plt.ylabel('Percentages of Colors')
plt.title("Comparitive Analysis")
  
plt.xticks(ind+width,['Color-1', 'Color-2', 'Color-3', 'Color-4', 'Color-5'])
plt.legend( (bar1, bar2, bar3), ('Kmeans', 'MiniBatchKmeans', 'Agglomerative') )
plt.show()

# %% [markdown]
# # **Comparitive Analysis of Performance Evaluation Metrics**

# %% [markdown]
# ## **Davies-Bouldin Index**

# %%
db_kmeans = 0.6668747506628151
db_minibatchkmeans = 0.6672735085635783
db_agglomerative = 0.6825747772013022

# %%
x = np.array(['db_kmeans', 'db_mbk', 'db_agglomerative'])  # X-axis points
y = [db_kmeans,db_minibatchkmeans,db_agglomerative]  # Y-axis points
  
plt.plot(x, y)  # Plot the chart
plt.show()

# %% [markdown]
# ## **Silhouette Coefficient**

# %%
silhouette_kmeans = 0.4615439020297648
silhouette_mbk = 0.46172167677968057
silhouette_agglomerative = 0.43930671627084406

# %%
x = np.array(['silhoutte_kmeans', 'silhoutte_mbk', 'silhoutte_agglomerative'])  # X-axis points
y = [silhouette_kmeans,silhouette_mbk,silhouette_agglomerative]  # Y-axis points
  
plt.plot(x, y)  # Plot the chart
plt.show()
